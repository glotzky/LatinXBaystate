# %%
import pandas as pd
import numpy as np

# %% [markdown]
# acs2016 = pd.read_csv('2016data.csv')
# acs2019 = pd.read_csv('2019data.csv')

# %%
tract2016 = pd.read_csv('2016Tract.csv')
tract2019 = pd.read_csv('2019Tract.csv')

# %%
tract2016.head()
# Out:
#                      id      City  Geographic Area Name  \
# 0  1400000US25005654100  Acushnet                  6541
# 1  1400000US25005654200  Acushnet                  6542
# 2  1400000US25009205100      Lynn                  2051
# 3  1400000US25009205200      Lynn                  2052
# 4  1400000US25009205300      Lynn                  2053
#
#    Estimate!!SEX AND AGE!!Total population  \
# 0                                     6858
# 1                                     3556
# 2                                     4893
# 3                                     5999
# 4                                     4206
#
#    Margin of Error!!SEX AND AGE!!Total population  \
# 0                                             217
# 1                                             216
# 2                                             417
# 3                                             751
# 4                                             230
#
#    Percent!!SEX AND AGE!!Total population  \
# ...

# %%
tract2019
# Out:
#                       id         City  Geographic Area Name  \
# 0   1400000US25005654100     Acushnet                  6541
# 1   1400000US25005654200     Acushnet                  6542
# 2   1400000US25009205100         Lynn                  2051
# 3   1400000US25009205200         Lynn                  2052
# 4   1400000US25009205300         Lynn                  2053
# ..                   ...          ...                   ...
# 77  1400000US25013802601  Springfield                  8026
# 78  1400000US25013802602  Springfield                  8026
# 79  1400000US25013813101    Southwick                  8131
# 80  1400000US25013813102    Southwick                  8131
# 81  1400000US25027752100      Douglas                  7521
#
#     Estimate!!SEX AND AGE!!Total population  \
# 0                                      6976
# 1                                      3553
# 2                                      5660
# 3                                      5395
# ...

# %% [markdown]
# acs2016

# %% [markdown]
# acs2019

# %%
#acs2016['Zipcode'] = acs2016['Zipcode'].astype(str)
#acs2019 = acs2019.rename(columns={"id":"Zipcode"})

# %%
#acs2016['Zipcode'] = acs2016['Zipcode'].astype(str)
#acs2019 = acs2019.rename(columns={"id":"Zipcode"})

tract2016['Geographic Area Name'] = tract2016['Geographic Area Name'].astype(str)
tract2016 = tract2016.rename(columns={'Geographic Area Name':"Tract"})


tract2019['Geographic Area Name'] = tract2019['Geographic Area Name'].astype(str)
tract2019 = tract2019.rename(columns={'Geographic Area Name':"Tract"})

# %%
#acs2019['Zipcode'] = acs2019['Zipcode'].astype(str)

# %%
#acs2016['Zipcode'] = acs2016['Zipcode'].str.zfill(5)
#acs2019['Zipcode'] = acs2019['Zipcode'].str.zfill(5)

# %%
for col in tract2016.columns: 
    print(col)

# %%
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Mexican
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Puerto Rican
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Cuban
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Other Hispanic or Latino
# Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino
# Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population
# Estimate Total population
# Zipcode
processed2016 = tract2016[['City','Tract','Estimate!!SEX AND AGE!!Total population','Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Mexican','Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Puerto Rican','Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Cuban','Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Other Hispanic or Latino','Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population']]

# %%
processed2019 = tract2019[['City','Tract','Estimate!!SEX AND AGE!!Total population','Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Mexican','Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Puerto Rican','Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Cuban','Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Other Hispanic or Latino','Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population']]

# %%
processed2016 = processed2016.rename(columns={'Estimate!!SEX AND AGE!!Total population': 'Estimate Total Population','Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Mexican': 'Estimate Mexican Population', "Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Puerto Rican": "Estimate Puerto Rican Population","Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Cuban": "Estimate Cuban Population","Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Other Hispanic or Latino":"Estimate Other Hispanic or Latino","Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population":"Estimate Voting Population: 18+"})

# %%
processed2019 = processed2019.rename(columns={'Estimate!!SEX AND AGE!!Total population': 'Estimate Total Population','Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Mexican': 'Estimate Mexican Population', "Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Puerto Rican": "Estimate Puerto Rican Population","Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Cuban": "Estimate Cuban Population","Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)!!Other Hispanic or Latino":"Estimate Other Hispanic or Latino","Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population":"Estimate Voting Population: 18+"})

# %% [markdown]
# city = []
# 2501
# 2502
# 2503
# 2504
# 2505
# 2506
# 2507
# 2508
# 2509
# 2510
# 2511
# 2512
# 2513
# 2514
# 2515
# 2516
# 2517
# 2518
# for row in processed2016['Zipcode']:
#     if row == '2501' or row == '2502' or row == '2503' or row == '2504':
#         city.append('Lawrence')
#     elif row == '01103' or row == '01104' or row == '01105' or row == '01107' or row == '01108' or row == '01109' or row == '01118' or row == '01119' or row == '01128' or row == '01129' or row == '01151':
#         city.append('Springfield')
#     elif row == '01901' or row ==  '01902' or row == '01904' or row == '01905':
#         city.append('Lynn')
#     elif row == '02743':
#         city.append('Acushnet')
#     elif row == '01077':
#         city.append('Southwick')
#     elif row == '01516':
#         city.append('Douglas')
#     else:
#         city.append('Missing City Name, Fix')

# %% [markdown]
# city

# %% [markdown]
# processed2016.insert(1,"City",city)

# %%
processed2016

# %% [markdown]
# city = []
# for row in processed2019['Zipcode']:
#     if row == '01840' or row == '01841' or row == '01842' or row == '01843':
#         city.append('Lawrence')
#     elif row == '01103' or row == '01104' or row == '01105' or row == '01107' or row == '01108' or row == '01109' or row == '01118' or row == '01119' or row == '01128' or row == '01129' or row == '01151':
#         city.append('Springfield')
#     elif row == '01901' or row ==  '01902' or row == '01904' or row == '01905':
#         city.append('Lynn')
#     elif row == '02743':
#         city.append('Acushnet')
#     elif row == '01077':
#         city.append('Southwick')
#     elif row == '01516':
#         city.append('Douglas')
#     else:
#         city.append('Missing City Name, Fix')

# %% [markdown]
# processed2019.insert(1,"City",city)

# %%
processed2019

# %%
pres2016 = pd.read_csv('2016PresidentPrecinct.csv')
pres2020 = pd.read_csv('2020PresidentPrecint.csv')
gov2018 = pd.read_csv('2018gov.csv')

# %%
pres2020.head()

# %%
gov2018.head()

# %%
procpres2016 = pres2016[['City/Town','Pct','Clinton/ Kaine','Trump/ Pence','Total Votes Cast']]
procpres2020 = pres2020[['City/Town','Pct','Joseph R. Biden, Jr.','Donald J. Trump','Total Votes Cast']]
procgov2018 = gov2018[['City/Town','Pct','Gonzalez and Palfrey','Baker and Polito','Total Votes Cast']]

# %%
procpres2016.drop([0])
procpres2020.drop([0])
procgov2018.drop([0])

# %%
pres2016 = procpres2016[(procpres2016['City/Town'] == 'Lawrence') | (procpres2016['City/Town'] == 'Springfield')| (procpres2016['City/Town'] == 'Lynn')|(procpres2016['City/Town'] == 'Acushnet')|(procpres2016['City/Town'] == 'Southwick')|(procpres2016['City/Town'] == 'Douglas')]

# %%
pres2016

# %%
pres2020 = procpres2020[(procpres2020['City/Town'] == 'Lawrence') | (procpres2020['City/Town'] == 'Springfield')| (procpres2020['City/Town'] == 'Lynn')|(procpres2020['City/Town'] == 'Acushnet')|(procpres2020['City/Town'] == 'Southwick')|(procpres2020['City/Town'] == 'Douglas')]

# %%
gov2018 = procgov2018[(procpres2016['City/Town'] == 'Lawrence') | (procgov2018['City/Town'] == 'Springfield')| (procgov2018['City/Town'] == 'Lynn')|(procgov2018['City/Town'] == 'Acushnet')|(procgov2018['City/Town'] == 'Southwick')|(procgov2018['City/Town'] == 'Douglas')]

# %%
pres2016 = pres2016.reset_index()
pres2016 = pres2016.drop(columns=['index'])
pres2020 = pres2020.reset_index()
pres2020 = pres2020.drop(columns=['index'])
gov2018 = gov2018.reset_index()
gov2018 = gov2018.drop(columns=['index'])

# %%
gov2018

# %% [markdown]
# processedTract2016 = processed2016
# processedTract2019 = processed2019
#
# processedTract2016.to_excel(r'ProcessedTract2016.xlsx', index = False)
# processedTract2019.to_excel(r'ProcessedTract2019.xlsx', index = False)
#
# #pres2016.to_csv(index = False)
# #pres2020.to_csv(index = False)
# #gov2018.to_csv(index = False)
#
# #to_excel(r'Demo2016.xlsx', index = False)
# #processed2019.to_excel(r'Demo2019.xlsx', index = False)
# #pres2016.to_excel(r'Pres2016.xlsx', index = False)
# #pres2020.to_excel(r'Pres2020.xlsx', index = False)
# #gov2018.to_excel(r'Gov2018.xlsx', index = False)

# %%
import sys
# !{sys.executable} -m pip install pygeos
# !{sys.executable} -m pip install shapely

# %%
import sys
# !{sys.executable} -m pip install geopandas

# %%
import shapely

# %% [markdown]
# cities = ['Acushnet','Douglas','Springfield','Lawrence','Lynn']

# %%
import shapely
from shapely.geometry import shape, mapping
import geopandas as gpd
from geopandas.tools import sjoin
import requests 
import json
# Out:
# /Users/gil/opt/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.0-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
import numpy as np
import pandas as pd

# %%
MA_p = gpd.read_file("wardsprecincts_poly/WARDSPRECINCTS_POLY.shp")

# %%
MA_p
# Out:
#                              WP_NAME  WARD PRECINCT DISTRICT  POP_2010  \
# 0         Braintree Town Precinct 5B  None       5B       5B      2883
# 1         Braintree Town Precinct 6A  None       6A       6A      3070
# 2         Braintree Town Precinct 6B  None       6B       6B      2925
# 3     Chelsea City Ward 1 Precinct 1     1        1      1-1      2295
# 4     Chelsea City Ward 1 Precinct 2     1        2      1-2      2108
# ...                              ...   ...      ...      ...       ...
# 2147   Boston City Ward 7 Precinct 8     7        8      7-8      1713
# 2148  Boston City Ward 12 Precinct 3    12        3     12-3      1082
# 2149  Boston City Ward 12 Precinct 2    12        2     12-2      3282
# 2150  Boston City Ward 11 Precinct 2    11        2     11-2      2172
# 2151  Boston City Ward 19 Precinct 4    19        4     19-4      1404
#
#            TOWN  TOWN_ID  AREA_SQMI   AREA_ACRES  YEAR    SHAPE_AREA  \
# ...

# %%
type(MA_p)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
MA_p.boundary.plot()

# %%
MA_p = MA_p.to_crs("EPSG:4326")
#MA_p[MA_p['TOWN'] == 'ABINGTON']

# %%
MA_pre = MA_p[['TOWN','WARD','PRECINCT','AREA_SQMI','AREA_ACRES','SHAPE_AREA','SHAPE_LEN','geometry']]

# %%
type(MA_p)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
MA_pre.head()
# Out:
#         TOWN  WARD PRECINCT  AREA_SQMI  AREA_ACRES    SHAPE_AREA  \
# 0  BRAINTREE  None       5B      1.217      778.80  3.151713e+06
# 1  BRAINTREE  None       6A      1.994     1275.96  5.163667e+06
# 2  BRAINTREE  None       6B      1.134      725.97  2.937925e+06
# 3    CHELSEA     1        1      0.139       88.82  3.594632e+05
# 4    CHELSEA     1        2      0.073       47.04  1.903509e+05
#
#       SHAPE_LEN                                           geometry
# 0   8711.937896  POLYGON ((-70.98701 42.20298, -70.98707 42.202...
# 1  11175.567690  POLYGON ((-70.97364 42.18719, -70.97367 42.186...
# 2   9455.882837  POLYGON ((-70.99625 42.18330, -70.99639 42.183...
# 3   3340.823153  POLYGON ((-71.02297 42.38672, -71.02301 42.386...
# 4   2247.883591  POLYGON ((-71.03354 42.38989, -71.03373 42.389...

# %%
base = MA_p.plot(color='white', edgecolor='black')

# %%
pp2020 = pd.read_csv('2020PresidentPrecint.csv')

# %%
pp2020.head()
# Out:
#   City/Town   Ward Precinct  Democratic  Republican  Libertarian   \
# 0  Abington   None        1      1037.0       764.0           29
# 1  Abington   None        2       960.0       838.0           23
# 2  Abington   None        3       954.0       848.0           31
# 3  Abington   None        4      1117.0       904.0           28
# 4  Abington   None        5      1141.0       882.0           35
#
#    Green-Rainbow  All Others  No Preference  Blanks  Total Votes Cast  \
# 0            6.0         8.0            0.0    16.0            1860.0
# 1           16.0         4.0            0.0     9.0            1850.0
# 2            8.0         3.0            0.0     9.0            1853.0
# 3            7.0         6.0            0.0    26.0            2088.0
# 4            8.0         3.0            0.0    15.0            2084.0
#
#    AREA_SQMI  AREA_ACRES    SHAPE_AREA    SHAPE_LEN  \
# 0      0.139       88.82  3.594632e+05  3340.823153
# ...

# %%
pp2020['City/Town'] = pp2020['City/Town'].str.upper()

# %%
pp2020.columns
pp2020.dtypes
# Out:
# City/Town            object
# Ward                 object
# Precinct             object
# Democratic          float64
# Republican          float64
#  Libertarian         object
# Green-Rainbow       float64
# All Others          float64
# No Preference       float64
# Blanks              float64
# Total Votes Cast    float64
# AREA_SQMI           float64
# AREA_ACRES          float64
# SHAPE_AREA          float64
# SHAPE_LEN           float64
# geometry             object
# dtype: object

# %%
pre2020 = pp2020[['City/Town','Ward','Precinct','Democratic','Republican','Total Votes Cast','AREA_SQMI','AREA_ACRES','SHAPE_AREA','SHAPE_LEN','geometry']]

# %%
pre2020.head()
# Out:
#   City/Town   Ward Precinct  Democratic  Republican  Total Votes Cast  \
# 0  ABINGTON   None        1      1037.0       764.0            1860.0
# 1  ABINGTON   None        2       960.0       838.0            1850.0
# 2  ABINGTON   None        3       954.0       848.0            1853.0
# 3  ABINGTON   None        4      1117.0       904.0            2088.0
# 4  ABINGTON   None        5      1141.0       882.0            2084.0
#
#    AREA_SQMI  AREA_ACRES    SHAPE_AREA    SHAPE_LEN  \
# 0      0.139       88.82  3.594632e+05  3340.823153
# 1      0.073       47.04  1.903509e+05  2247.883591
# 2      0.061       39.11  1.582884e+05  1947.861606
# 3      0.275      176.02  7.123119e+05  6290.864945
# 4      0.814      520.89  2.107966e+06  7623.552388
#
#                                             geometry
# 0  POLYGON ((-71.02296599966095 42.38671900036098...
# 1  POLYGON ((-71.03353799997382 42.38988500010097...
# 2  POLYGON ((-71.02608999969314 42.39073199998803...
# ...

# %%
pre2020['% Democratic'] = pre2020['Democratic']/(pre2020['Total Votes Cast'])
pre2020['% Republican'] = pre2020['Republican']/(pre2020['Total Votes Cast'])
# Out:
# <ipython-input-117-d63987db11ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre2020['% Democratic'] = pre2020['Democratic']/(pre2020['Total Votes Cast'])
# <ipython-input-117-d63987db11ac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre2020['% Republican'] = pre2020['Republican']/(pre2020['Total Votes Cast'])

# %%
pre2020.head()
# Out:
#   City/Town   Ward Precinct  Democratic  Republican  Total Votes Cast  \
# 0  ABINGTON   None        1      1037.0       764.0            1860.0
# 1  ABINGTON   None        2       960.0       838.0            1850.0
# 2  ABINGTON   None        3       954.0       848.0            1853.0
# 3  ABINGTON   None        4      1117.0       904.0            2088.0
# 4  ABINGTON   None        5      1141.0       882.0            2084.0
#
#    AREA_SQMI  AREA_ACRES    SHAPE_AREA    SHAPE_LEN  \
# 0      0.139       88.82  3.594632e+05  3340.823153
# 1      0.073       47.04  1.903509e+05  2247.883591
# 2      0.061       39.11  1.582884e+05  1947.861606
# 3      0.275      176.02  7.123119e+05  6290.864945
# 4      0.814      520.89  2.107966e+06  7623.552388
#
#                                             geometry  % Democratic  \
# 0  POLYGON ((-71.02296599966095 42.38671900036098...      0.557527
# 1  POLYGON ((-71.03353799997382 42.38988500010097...      0.518919
# ...

# %% [markdown]
# pre2020 = pre2020.rename(columns={"City/Town":"TOWN","Ward":"WARD","Precinct":"PRECINCT"})

# %%
type(pre2020)
# Out:
# pandas.core.frame.DataFrame

# %%
Rep2020high = pre2020.copy()
Re2020low = pre2020.copy()

Dem2020high = pre2020.copy()
Dem2020low = pre2020.copy()

# %%
Rep2020high = pre2020.loc[(pre2020["% Republican"] > .65)]
Rep2020low = pre2020.loc[(pre2020["% Republican"] <= .65)&(pre2020["% Republican"] > .5)]
Dem2020high = pre2020.loc[(pre2020["% Democratic"] >.65)]
Dem2020low = pre2020.loc[(pre2020["% Republican"] <= .65)&(pre2020["% Republican"] > .5)]

# %%
Rep2020low.head()
# Out:
#    City/Town   Ward Precinct  Democratic  Republican  Total Votes Cast  \
# 11  ACUSHNET   None        1       815.0       924.0            1791.0
# 12  ACUSHNET   None        2       932.0      1176.0            2165.0
# 13  ACUSHNET   None        3       917.0      1190.0            2170.0
# 19    AGAWAM   None        1       825.0       922.0            1784.0
# 20    AGAWAM   None        2      1036.0      1121.0            2215.0
#
#     AREA_SQMI  AREA_ACRES    SHAPE_AREA    SHAPE_LEN  \
# 11      0.512      327.60  1.325749e+06  5608.531702
# 12      0.319      204.08  8.258979e+05  5827.944762
# 13      0.638      408.36  1.652575e+06  9463.213094
# 19      0.747      477.88  1.933918e+06  6660.125979
# 20      0.346      221.24  8.953325e+05  5144.320799
#
#                                              geometry  % Democratic  \
# 11  POLYGON ((-72.59615100048052 42.21183799979418...      0.455053
# 12  POLYGON ((-71.0861090003629 42.77260499956517,...      0.430485
# ...

# %%
Rep2020HighG = gpd.GeoDataFrame(
    Rep2020high, geometry=Rep2020high['geometry'])
Rep2020LowG = gpd.GeoDataFrame(
    Rep2020low, geometry=Rep2020low['geometry'])
Dem2020HighG = gpd.GeoDataFrame(
    Dem2020high, geometry=geometry)
Dem2020LowG = gpd.GeoDataFrame(
    Dem2020low, geometry=geometry)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-cf7a03005667> in <module>
#       1 Rep2020HighG = gpd.GeoDataFrame(
#       2     Rep2020high, geometry=Rep2020high['geometry'])
# ----> 3 Rep2020LowG = gpd.GeoDataFrame(
#       4     Rep2020low, geometry=Rep2020low['geometry'])
#       5 Dem2020HighG = gpd.GeoDataFrame(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py in __init__(self, geometry, crs, *args, **kwargs)
#     165                 )
#     166                 # TODO: raise error in 0.9 or 0.10.
# --> 167             self.set_geometry(geometry, inplace=True)
#     168
#     169         if geometry is None and crs:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py in set_geometry(self, col, drop, inplace, crs)
#     293
#     294         # Check that we are using a listlike of geometries
# ...

# %%
MA_df = gpd.read_file("CENSUS2010_BLK_BG_TRCT_SHP/CENSUS2010TRACTS_POLY.shp")
MA_df
# Out:
#      STATEFP10 COUNTYFP10 TRACTCE10      GEOID10   NAME10  \
# 0           25        021    418003  25021418003  4180.03
# 1           25        021    417701  25021417701  4177.01
# 2           25        021    417702  25021417702  4177.02
# 3           25        021    418102  25021418102  4181.02
# 4           25        021    418004  25021418004  4180.04
# ...        ...        ...       ...          ...      ...
# 1467        25        027    709501  25027709501  7095.01
# 1468        25        027    709502  25027709502  7095.02
# 1469        25        027    730801  25027730801  7308.01
# 1470        25        027    710800  25027710800     7108
# 1471        25        027    732600  25027732600     7326
#
#                 NAMELSAD10 MTFCC10    ALAND10  AWATER10   INTPTLAT10  ...  \
# 0     Census Tract 4180.03   G5020  1705668.0    2936.0  +42.2350240  ...
# 1     Census Tract 4177.01   G5020  1543651.0   12275.0  +42.2523398  ...
# ...

# %%
MA_df.boundary.plot()

# %%
base = MA_df.plot(color='white', edgecolor='black')

# %%
MA_df = MA_df.to_crs("EPSG:4326")
MA_df
# Out:
#      STATEFP10 COUNTYFP10 TRACTCE10      GEOID10   NAME10  \
# 0           25        021    418003  25021418003  4180.03
# 1           25        021    417701  25021417701  4177.01
# 2           25        021    417702  25021417702  4177.02
# 3           25        021    418102  25021418102  4181.02
# 4           25        021    418004  25021418004  4180.04
# ...        ...        ...       ...          ...      ...
# 1467        25        027    709501  25027709501  7095.01
# 1468        25        027    709502  25027709502  7095.02
# 1469        25        027    730801  25027730801  7308.01
# 1470        25        027    710800  25027710800     7108
# 1471        25        027    732600  25027732600     7326
#
#                 NAMELSAD10 MTFCC10    ALAND10  AWATER10   INTPTLAT10  ...  \
# 0     Census Tract 4180.03   G5020  1705668.0    2936.0  +42.2350240  ...
# 1     Census Tract 4177.01   G5020  1543651.0   12275.0  +42.2523398  ...
# ...

# %%
for col in MA_df.columns: 
    print(col)
# Out:
# STATEFP10
# COUNTYFP10
# TRACTCE10
# GEOID10
# NAME10
# NAMELSAD10
# MTFCC10
# ALAND10
# AWATER10
# INTPTLAT10
# INTPTLON10
# AREA_SQFT
# AREA_ACRES
# POP100_RE
# HU100_RE
# LOGPL94171
# LOGSF1
# LOGACS0610
# LOGSF1C
# SHAPE_AREA
# SHAPE_LEN
# geometry

# %%
MAlist = MA_df.rename(columns={"STATEFP10":"State","COUNTYFP10":"County","GEOID10":"GeoID","NAME10":"Tract","INTPTLAT10":"Latitude","INTPTLON10":"Longitude",})

# %%
for col in MAlist.columns: 
    print(col)
# Out:
# State
# County
# TRACTCE10
# GeoID
# Tract
# NAMELSAD10
# MTFCC10
# ALAND10
# AWATER10
# Latitude
# Longitude
# AREA_SQFT
# AREA_ACRES
# POP100_RE
# HU100_RE
# LOGPL94171
# LOGSF1
# LOGACS0610
# LOGSF1C
# SHAPE_AREA
# SHAPE_LEN
# geometry

# %%
MAlist = MAlist.drop(columns =['TRACTCE10'])

# %%
for col in MAlist.columns: 
    print(col)
# Out:
# State
# County
# GeoID
# Tract
# NAMELSAD10
# MTFCC10
# ALAND10
# AWATER10
# Latitude
# Longitude
# AREA_SQFT
# AREA_ACRES
# POP100_RE
# HU100_RE
# LOGPL94171
# LOGSF1
# LOGACS0610
# LOGSF1C
# SHAPE_AREA
# SHAPE_LEN
# geometry

# %%
MAlist=MAlist[['State','County','Tract','GeoID','Latitude','Longitude','AREA_SQFT','AREA_ACRES','SHAPE_AREA','geometry']]

# %%
for col in MAlist.columns: 
    print(col)
# Out:
# State
# County
# Tract
# GeoID
# Latitude
# Longitude
# AREA_SQFT
# AREA_ACRES
# SHAPE_AREA
# geometry

# %%
MAlist.head()
# Out:
#   State County    Tract        GeoID     Latitude     Longitude    AREA_SQFT  \
# 0    25    021  4180.03  25021418003  +42.2350240  -071.0200129  18389900.39
# 1    25    021  4177.01  25021417701  +42.2523398  -071.0007484  16746649.09
# 2    25    021  4177.02  25021417702  +42.2582818  -070.9887207  18142381.08
# 3    25    021  4181.02  25021418102  +42.2470410  -071.0211009   8326047.44
# 4    25    021  4180.04  25021418004  +42.2383744  -071.0104974  14169248.82
#
#    AREA_ACRES    SHAPE_AREA                                           geometry
# 0    422.1740  1.708484e+06  POLYGON ((-71.00721 42.23013, -71.00807 42.229...
# 1    384.4502  1.555821e+06  POLYGON ((-71.00345 42.26050, -71.00326 42.260...
# 2    416.4918  1.685489e+06  POLYGON ((-70.98695 42.26423, -70.98758 42.263...
# 3    191.1397  7.735182e+05  POLYGON ((-71.01081 42.24440, -71.01056 42.244...
# 4    325.2812  1.316372e+06  POLYGON ((-71.00700 42.24409, -71.00684 42.244...

# %%
MAlist["Tract"]  = MAlist["Tract"].astype(float)

# %%
MAlist["Tract"] = MAlist["Tract"].astype(int)

# %%
MAlist.size
# Out:
# 14720

# %%
MAlist.head()
# Out:
#   State County  Tract        GeoID     Latitude     Longitude    AREA_SQFT  \
# 0    25    021   4180  25021418003  +42.2350240  -071.0200129  18389900.39
# 1    25    021   4177  25021417701  +42.2523398  -071.0007484  16746649.09
# 2    25    021   4177  25021417702  +42.2582818  -070.9887207  18142381.08
# 3    25    021   4181  25021418102  +42.2470410  -071.0211009   8326047.44
# 4    25    021   4180  25021418004  +42.2383744  -071.0104974  14169248.82
#
#    AREA_ACRES    SHAPE_AREA                                           geometry
# 0    422.1740  1.708484e+06  POLYGON ((-71.00721 42.23013, -71.00807 42.229...
# 1    384.4502  1.555821e+06  POLYGON ((-71.00345 42.26050, -71.00326 42.260...
# 2    416.4918  1.685489e+06  POLYGON ((-70.98695 42.26423, -70.98758 42.263...
# 3    191.1397  7.735182e+05  POLYGON ((-71.01081 42.24440, -71.01056 42.244...
# 4    325.2812  1.316372e+06  POLYGON ((-71.00700 42.24409, -71.00684 42.244...

# %% [markdown]
# MAList2 = gpd.GeoDataFrame(pd.concat([MAlist(float("nan"), columns=['City', 'Precinct', 'Joseph R. Biden, Jr.',
#        'Percentage of Total', 'Donald J. Trump', 'Percentage of Total.1',
#        'Total Votes Cast', 'Estimate Total Population',
#        'Estimate Mexican Population', 'Estimate Puerto Rican Population',
#        'Estimate Cuban Population', 'Estimate Other Hispanic or Latino',
#        'LatinX Pop Percentage', 'Estimate Voting Population: 18+',
#        'City LatinX Pop %', 'City Dem Votes %', 'City Rep Votes %']) for i in range(MAlist.size)],ignore_index=True))

# %%
MAlist.plot()

# %%
tractsprecincts = pd.read_csv('TractsPrecints2020.csv')

# %%
tractsprecincts.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bbc984b80dda> in <module>
# ----> 1 tractsprecincts.shape
#
# NameError: name 'tractsprecincts' is not defined

# %%
tractsprecincts.columns
# Out:
# Index(['City', 'Tracts', 'Precinct', 'Joseph R. Biden, Jr.',
#        'Percentage of Total', 'Donald J. Trump', 'Percentage of Total.1',
#        'Total Votes Cast', 'Estimate Total Population',
#        'Estimate Mexican Population', 'Estimate Puerto Rican Population',
#        'Estimate Cuban Population', 'Estimate Other Hispanic or Latino',
#        'LatinX Pop Percentage', 'Estimate Voting Population: 18+',
#        'City LatinX Pop %', 'City Dem Votes %', 'City Rep Votes %', 'State',
#        'County', 'Tract', 'GeoID', 'Latitude', 'Longitude', 'AREA_SQFT',
#        'AREA_ACRES', 'SHAPE_AREA', 'geometry'],
#       dtype='object')

# %% [markdown]
# #### 50-55% - light blue 56-100% - dark blue; 0-45% dark red 46-49 light red

# %%
type(tractsprecincts)
# Out:
# pandas.core.frame.DataFrame

# %%
type(MAlist)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
TractPrecinct2016 = pd.read_csv('TractsPrecincts2016.csv')

# %%
TractPrecinct2020 = pd.read_csv('TractsPrecints2020.csv')

# %%
tracts = []
for tract in TractPrecinct2016['Tracts']:
     tracts.append(tract)

# %%
tracts
# Out:
# [2051,
#  2052,
#  2053,
#  2054,
#  2055,
#  2056,
#  2057,
#  2058,
#  2059,
#  2060,
#  2061,
#  2062,
#  2063,
#  2064,
#  2065,
#  2066,
#  2067,
#  2068,
#  2069,
#  2070,
#  2071,
#  2072,
#  2501,
#  2502,
#  2503,
#  2504,
#  2505,
#  2506,
#  2507,
#  2508,
#  2510,
#  2511,
#  2512,
#  2513,
#  2514,
#  2515,
#  2516,
#  2517,
#  2518,
#  6541,
#  6542,
#  7521,
#  8001,
#  8002,
#  8003,
#  8004,
#  8005,
#  8006,
#  8007,
#  8008,
#  8009,
#  8011,
#  8012,
#  8013,
#  8014,
#  8015,
#  8016,
#  8017,
#  8018,
#  8019,
#  8020,
#  8021,
#  8022,
#  8023,
#  8024,
#  8025,
#  8026,
#  8131]

# %%
TractPrecinct2016
# Out:
#            City  Tracts            Precinct Hillary Clinton  \
# 0          Lynn    2051                 2-1            1075
# 1          Lynn    2052                 1-4             968
# 2          Lynn    2053                 1-2             976
# 3          Lynn    2054                 1-1             930
# 4          Lynn    2055                 5-1             762
# ..          ...     ...                 ...             ...
# 63  Springfield    8023       6-E, 3-G, 3-H            1490
# 64  Springfield    8024                 7-A             638
# 65  Springfield    8025  6-H, 7-B, 7-C, 7-D            2795
# 66  Springfield    8026       6-D, 6-F, 6-G            1827
# 67    Southwick    8131               1,2,3            1859
#
#    Percentage of Total  Donald J. Trump Percentage of Total.1  \
# 0               59.39%              735                40.61%
# 1               64.23%              539                35.77%
# ...

# %%
TractPrecinct2016['Percentage of Total.1'] = TractPrecinct2016['Percentage of Total.1'].str.rstrip('%').astype('float') / 100.0
TractPrecinct2020['Percentage of Total.1'] = TractPrecinct2020['Percentage of Total.1'].str.rstrip('%').astype('float') / 100.0
TractPrecinct2020['Percentage of Total'] = TractPrecinct2020['Percentage of Total'].str.rstrip('%').astype('float') / 100.0
TractPrecinct2016['Percentage of Total'] = TractPrecinct2016['Percentage of Total'].str.rstrip('%').astype('float') / 100.0

# %% [markdown]
# ### Make decisions here

# %%
#TractPrecinct2016
Rep2016low = TractPrecinct2016.copy()
Rep2016high = TractPrecinct2016.copy()
Rep2020high = TractPrecinct2020.copy()
Re2020low = TractPrecinct2020.copy()

Dem2016low = TractPrecinct2016.copy()
Dem2016high = TractPrecinct2016.copy()
Dem2020high = TractPrecinct2020.copy()
Dem2020low = TractPrecinct2020.copy()
#50-55% - light blue 56-100% - dark blue; 0-45% dark red 46-49 light red

# %%
TractPrecinct2016.shape
# Out:
# (68, 28)

# %%
TractPrecinct2016.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-078c5ea041e3> in <module>
# ----> 1 TractPrecinct2016.head()
#
# NameError: name 'TractPrecinct2016' is not defined

# %%
Rep2016high = TractPrecinct2016.loc[(TractPrecinct2016["Percentage of Total"] < .35)]
Rep2016low = TractPrecinct2016.loc[(TractPrecinct2016["Percentage of Total"] >= .35)&(TractPrecinct2016["Percentage of Total"] < .5)]
Rep2020high = TractPrecinct2020.loc[(TractPrecinct2020["Percentage of Total"] < .35)]
Rep2020low = TractPrecinct2020.loc[(TractPrecinct2020["Percentage of Total"] >= .35)&(TractPrecinct2016["Percentage of Total"] < .5)]

# %%
#50-55% - light blue 56-100%

# %%
Dem2016high = TractPrecinct2016.loc[(TractPrecinct2016["Percentage of Total"] > .65)]
Dem2016low = TractPrecinct2016.loc[(TractPrecinct2016["Percentage of Total"] <= .65)&(TractPrecinct2016["Percentage of Total"] >= .5)]
Dem2020high = TractPrecinct2020.loc[(TractPrecinct2020["Percentage of Total"] > .65)]
Dem2020low = TractPrecinct2020.loc[(TractPrecinct2020["Percentage of Total"] <= .65)&(TractPrecinct2016["Percentage of Total"] >= .5)]

# %%
Rep2016highG = gpd.GeoDataFrame(
    Rep2016high, geometry=gpd.points_from_xy(Rep2016high.Longitude, Rep2016high.Latitude))
Rep2016lowG = gpd.GeoDataFrame(
    Rep2016low, geometry=gpd.points_from_xy(Rep2016low.Longitude, Rep2016low.Latitude))
Rep2020highG = gpd.GeoDataFrame(
    Rep2020high, geometry=gpd.points_from_xy(Rep2020high.Longitude, Rep2020high.Latitude))
Rep2020lowG = gpd.GeoDataFrame(
    Rep2020low, geometry=gpd.points_from_xy(Rep2020low.Longitude, Rep2020low.Latitude))
Dem2016highG = gpd.GeoDataFrame(
    Dem2016high, geometry=gpd.points_from_xy(Dem2016high.Longitude, Dem2016high.Latitude))
Dem2016lowG = gpd.GeoDataFrame(
    Dem2016low, geometry=gpd.points_from_xy(Dem2016low.Longitude, Dem2016low.Latitude))
Dem2020highG = gpd.GeoDataFrame(
    Dem2020high, geometry=gpd.points_from_xy(Dem2020high.Longitude, Dem2020high.Latitude))
Dem2020lowG = gpd.GeoDataFrame(
    Dem2020low, geometry=gpd.points_from_xy(Dem2020low.Longitude, Dem2020low.Latitude))

# %% [markdown]
# TractPrecinct2016["Percentage of Total"] < .45

# %%
Rep2016low
# Out:
#         City  Tracts Precinct Hillary Clinton  Percentage of Total  \
# 39  Acushnet    6541        2             756               0.4202
# 40  Acushnet    6542      1,3            1645               0.4788
# 41   Douglas    7521    1,2,3            1780               0.3987
#
#     Donald J. Trump  Percentage of Total.1 Total Votes Cast  \
# 39             1043                 0.5798             1799
# 40             1791                 0.5212             3436
# 41             2685                 0.6013             4465
#
#     Estimate Total Population  Estimate Mexican Population  ...  State  \
# 39                       6858                            0  ...     25
# 40                       3556                            0  ...     25
# 41                       8665                          203  ...     25
#
#     County  Tract        GeoID   Latitude  Longitude     AREA_SQFT  \
# 39       5   6541  25005654100  41.709206 -70.898436  4.772407e+08
# ...

# %%
tpdf2016 = gpd.GeoDataFrame(
    TractPrecinct2016, geometry=gpd.points_from_xy(TractPrecinct2016.Longitude, TractPrecinct2016.Latitude))
tpdf2016
# Out:
#            City  Tracts            Precinct Hillary Clinton  \
# 0          Lynn    2051                 2-1            1075
# 1          Lynn    2052                 1-4             968
# 2          Lynn    2053                 1-2             976
# 3          Lynn    2054                 1-1             930
# 4          Lynn    2055                 5-1             762
# ..          ...     ...                 ...             ...
# 63  Springfield    8023       6-E, 3-G, 3-H            1490
# 64  Springfield    8024                 7-A             638
# 65  Springfield    8025  6-H, 7-B, 7-C, 7-D            2795
# 66  Springfield    8026       6-D, 6-F, 6-G            1827
# 67    Southwick    8131               1,2,3            1859
#
#     Percentage of Total  Donald J. Trump  Percentage of Total.1  \
# 0                0.5939              735                 0.4061
# 1                0.6423              539                 0.3577
# ...

# %%
tpdf2020 = gpd.GeoDataFrame(
    TractPrecinct2020, geometry=gpd.points_from_xy(TractPrecinct2020.Longitude, TractPrecinct2020.Latitude))
tpdf2020
# Out:
#            City  Tracts            Precinct Joseph R. Biden, Jr.  \
# 0          Lynn    2051                 2-1                 1225
# 1          Lynn    2052                 1-4                1,150
# 2          Lynn    2053                 1-2                1,238
# 3          Lynn    2054                 1-1                1,060
# 4          Lynn    2055                 5-1                  958
# ..          ...     ...                 ...                  ...
# 63  Springfield    8023       6-E, 3-G, 3-H                 1343
# 64  Springfield    8024                 7-A                  772
# 65  Springfield    8025  6-H, 7-B, 7-C, 7-D                 3193
# 66  Springfield    8026       6-D, 6-F, 6-G                 2053
# 67    Southwick    8131               1,2,3                 2360
#
#     Percentage of Total Donald J. Trump  Percentage of Total.1  \
# 0                0.6119             725                 0.3621
# ...

# %%
tpdf2016.plot()

# %%
# !pip3 install mapclassify

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.set_aspect('equal')
MA_df.plot(ax=ax, color='white', edgecolor='black')
#base = MA_df.plot(color='white', edgecolor='black')
#tpdf2016.plot(ax=base, marker='o', color='red', markersize=5)
#test20.plot(ax=ax, marker='x', color='blue', markersize=5)
#test21.plot(ax=ax, marker='o', color='red', markersize=5)
Dem2016highG.plot(ax=ax, marker='o', color='blue', markersize=5)
Dem2016lowG.plot(ax=ax, marker='o', color='lightskyblue', markersize=5)
Rep2016highG.plot(ax=ax, marker='o', color='red', markersize=5)
Rep2016lowG.plot(ax=ax, marker='o', color='salmon', markersize=5)
plt.legend(('High Democratic Support', 'Low Democratic Support','High Republican Support', 'Low Democratic Support'), loc = 'lower left')
plt.title("Geospatial Analysis of 2016 Presidential Election")
plt.show()
#plt.savefig('Map2016.png')

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
MA_df.plot(ax=ax, color='white', edgecolor='black')
#base = MA_df.plot(color='white', edgecolor='black')
#tpdf2016.plot(ax=base, marker='o', color='red', markersize=5)
#test20.plot(ax=ax, marker='x', color='blue', markersize=5)
#test21.plot(ax=ax, marker='o', color='red', markersize=5)
Dem2020highG.plot(ax=ax, marker='o', color='blue', markersize=5)
Dem2020lowG.plot(ax=ax, marker='o', color='lightskyblue', markersize=5)
#Rep2020highG.plot(ax=ax, marker='o', color='red', markersize=5)
Rep2020lowG.plot(ax=ax, marker='o', color='salmon', markersize=5)
plt.legend(('High Democratic Support', 'Low Democratic Support','Low Republican Support'), loc = 'lower left')
plt.title("Geospatial Analysis of 2020 Presidential Election")
plt.show()
#plt.savefig('Map2020.png')

# %%
Rep2020highG.head()
# Out:
# Empty GeoDataFrame
# Columns: [City, Tracts, Precinct, Joseph R. Biden, Jr., Percentage of Total, Donald J. Trump, Percentage of Total.1, Total Votes Cast, Estimate Total Population, Estimate Mexican Population, Estimate Puerto Rican Population, Estimate Cuban Population, Estimate Other Hispanic or Latino, LatinX Pop Percentage, Estimate Voting Population: 18+, City LatinX Pop %, City Dem Votes %, City Rep Votes %, State, County, Tract, GeoID, Latitude, Longitude, AREA_SQFT, AREA_ACRES, SHAPE_AREA, geometry]
# Index: []
#
# [0 rows x 28 columns]

# %%
TractPrecinct2020
# Out:
#            City  Tracts            Precinct Joseph R. Biden, Jr.  \
# 0          Lynn    2051                 2-1                 1225
# 1          Lynn    2052                 1-4                1,150
# 2          Lynn    2053                 1-2                1,238
# 3          Lynn    2054                 1-1                1,060
# 4          Lynn    2055                 5-1                  958
# ..          ...     ...                 ...                  ...
# 63  Springfield    8023       6-E, 3-G, 3-H                 1343
# 64  Springfield    8024                 7-A                  772
# 65  Springfield    8025  6-H, 7-B, 7-C, 7-D                 3193
# 66  Springfield    8026       6-D, 6-F, 6-G                 2053
# 67    Southwick    8131               1,2,3                 2360
#
#     Percentage of Total Donald J. Trump  Percentage of Total.1  \
# 0                0.6119             725                 0.3621
# ...

# %%
MAlist.head()

# %%
gpd.overlay(tpdf2016, MAlist, how='identity')

# %%
merged2016 = sjoin(tpdf2016, MAlist, how='left', op='within')

# %%
merged2016

# %%
pd.concat([tpdf2016, MAlist.reindex(tpdf2016.index)], axis=1)

# %%
merged2020 = sjoin(tpdf2020, MAlist, how='left', op='within')

# %% [markdown]
# tracts = []
# for tract in tractsprecincts['Tracts']:
#         tracts.append(tract)

# %% [markdown]
# merged2016.to_csv("Spatial_merge2016.csv", encoding = "utf-8")
# merged2020.to_csv("Spatial_merge2020.csv", encoding = "utf-8")

# %% [markdown]
# tracts = tracts[:-3]
# tracts[30] = '2509'
# tracts

# %%
merged2016.columns

# %% [markdown]
# MAlist.to_excel(r'MAlist.xlsx', index = False)

# %%
MAlist.head()

# %%
MA_df.plot()

# %%
MA_pre.to_excel(r'PrecinctGro.xlsx', index = False)

# %% [markdown]
# join = gpd.sjoin(MA_df, MA_df4, how="left", op="intersects")
