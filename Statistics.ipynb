# %% [markdown]
# ## Read in merged CSV files

# %%
import pandas as pd
import numpy as np

pres_data = pd.read_csv('MergedMassData.csv')

gov_data = pd.read_csv('MergedMassDataGov.csv')

# %%
pres_data.columns
# Out:
# Index(['STATEFP10', 'COUNTYFP10', 'TRACTCE10', 'GEOID10', 'NAME10',
#        'NAMELSAD10', 'MTFCC10', 'ALAND10', 'AWATER10', 'INTPTLAT10',
#        'INTPTLON10', 'AREA_SQFT', 'AREA_ACRES_left', 'POP100_RE', 'HU100_RE',
#        'LOGPL94171', 'LOGSF1', 'LOGACS0610', 'LOGSF1C', 'SHAPE_AREA_left',
#        'SHAPE_LEN_left', 'geometry', 'Tract', '% Point Change in LatinX Pop.',
#        '% Point Change in Total Pop.', '% Point Puerto Rican Change',
#        '% Point Mexican Change', '% Point Cuban Change',
#        '% Point Other LatinX Change', 'Total Population 2016',
#        'LatinX Population 2016', 'Mexican 2016', 'Puerto Rican 2016',
#        'Cuban 2016', 'Other LatinX 2016', 'Total Population 2019',
#        'LatinX Population 2019', 'Mexican 2019', 'Puerto Rican 2019',
#        'Cuban 2019', 'Other LatinX 2019', 'index_right', 'WP_NAME', 'WARD',
#        'PRECINCT', 'DISTRICT', 'POP_2010', 'TOWN', 'TOWN_ID', 'AREA_SQMI',
#        'AREA_ACRES_right', 'YEAR', 'SHAPE_AREA_right', 'SHAPE_LEN_right',
#        'City/Town', 'Pct', 'Ward', 'Democratic 2016', 'Republican 2016',
#        'Total Votes Cast', 'Democratic 2020', 'Republican 2020',
#        'Total Votes Cast 2020', '% Point Change in Democratic Votes',
#        '% Change in Total Votes', '% Point Change in Republican Votes'],
#       dtype='object')

# %%
pres_city = pres_data[['Tract', 'Total Population 2016', 'LatinX Population 2016',
       'Mexican 2016', 'Puerto Rican 2016', 'Cuban 2016', 'Other LatinX 2016',
       'Total Population 2019', 'LatinX Population 2019', 'Mexican 2019',
       'Puerto Rican 2019', 'Cuban 2019', 'Other LatinX 2019', 'City/Town',
       'Democratic 2016', 'Republican 2016', 'Total Votes Cast',
       'Democratic 2020', 'Republican 2020', 'Total Votes Cast 2020']]

# %%
#convert Tract column to type str

pres_city['Tract'] = pres_city['Tract'].astype(str)
# Out:
# <ipython-input-4-34c4ffa88167>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pres_city['Tract'] = pres_city['Tract'].astype(str)

# %%
pres_city.dtypes
# Out:
# Tract                      object
# Total Population 2016       int64
# LatinX Population 2016      int64
# Mexican 2016                int64
# Puerto Rican 2016           int64
# Cuban 2016                  int64
# Other LatinX 2016           int64
# Total Population 2019       int64
# LatinX Population 2019      int64
# Mexican 2019                int64
# Puerto Rican 2019           int64
# Cuban 2019                  int64
# Other LatinX 2019           int64
# City/Town                  object
# Democratic 2016           float64
# Republican 2016           float64
# Total Votes Cast          float64
# Democratic 2020           float64
# Republican 2020           float64
# Total Votes Cast 2020     float64
# dtype: object

# %%
#Drop Tract Duplicates 
pres_city = pres_city.drop_duplicates(['Tract'])

#Sum up rows by Town 
pres_city = pres_city.groupby('City/Town').sum()

# %% [markdown]
# ## Add columns with percent change

# %%
pres_city['% LatinX 2016'] = pres_city['LatinX Population 2016']/pres_city['Total Population 2016']

pres_city['% LatinX 2019'] = pres_city['LatinX Population 2019']/pres_city['Total Population 2019']


pres_city = pres_city.rename(columns = {'Total Votes Cast':'Total Votes Cast 2016'})


pres_city['% Democratic 2016'] = pres_city['Democratic 2016']/pres_city['Total Votes Cast 2016']

pres_city['% Democratic 2020'] = pres_city['Democratic 2020']/pres_city['Total Votes Cast 2020']


pres_city['% Republican 2016'] = pres_city['Republican 2016']/pres_city['Total Votes Cast 2016']

pres_city['% Republican 2020'] = pres_city['Republican 2020']/pres_city['Total Votes Cast 2020']

# %% [markdown]
# ## Add columns with percentage point change

# %%
pres_city['Democratic Percentage point Change'] = (pres_city['% Democratic 2020'] - pres_city['% Democratic 2016'])*100

pres_city['Republican Percentage point Change'] = (pres_city['% Republican 2020'] - pres_city['% Republican 2016'])*100

pres_city['Change LatinX'] = pres_city['% LatinX 2019'] - pres_city['% LatinX 2016']

# %%
pres_city.head()
# Out:
#            Total Population 2016  LatinX Population 2016  Mexican 2016  \
# City/Town
# ABINGTON                   16586                     361            63
# ACTON                      18514                     292            27
# ACUSHNET                    7589                     245            13
# ADAMS                       7258                     189            16
# AGAWAM                     48369                    5396           115
#
#            Puerto Rican 2016  Cuban 2016  Other LatinX 2016  \
# City/Town
# ABINGTON                 157           0                141
# ACTON                     47          19                199
# ACUSHNET                 140          51                 41
# ADAMS                    112           0                 61
# AGAWAM                  4611         111                559
#
#            Total Population 2019  LatinX Population 2019  Mexican 2019  \
# City/Town
# ABINGTON                   17908                     342            98
# ACTON                      19437                     709            19
# ACUSHNET                    7718                     321            11
# ADAMS                       6748                     350            68
# AGAWAM                     48276                    5607           227
#
#            Puerto Rican 2019  ...  Total Votes Cast 2020  % LatinX 2016  \
# City/Town                     ...
# ABINGTON                  60  ...                 5553.0       0.021765
# ACTON                    102  ...                 9784.0       0.015772
# ACUSHNET                 194  ...                 3961.0       0.032284
# ADAMS                    218  ...                 2809.0       0.026040
# AGAWAM                  4945  ...                18782.0       0.111559
#
#            % LatinX 2019  % Democratic 2016  % Democratic 2020  \
# City/Town
# ABINGTON        0.019098           0.444159           0.517558
# ACTON           0.036477           0.711616           0.794665
# ACUSHNET        0.041591           0.442919           0.437263
# ADAMS           0.051867           0.617761           0.666429
# AGAWAM          0.116145           0.423589           0.485412
#
#            % Republican 2016  % Republican 2020  \
# City/Town
# ABINGTON            0.469219           0.454529
# ACTON               0.195389           0.175797
# ACUSHNET            0.482229           0.533704
# ADAMS               0.289961           0.302955
# AGAWAM              0.495315           0.489990
#
#            Democratic Percentage point Change  \
# City/Town
# ABINGTON                             7.339864
# ACTON                                8.304882
# ACUSHNET                            -0.565537
# ADAMS                                4.866872
# AGAWAM                               6.182295
#
#            Republican Percentage point Change  Change LatinX
# City/Town
# ABINGTON                            -1.468954      -0.002668
# ACTON                               -1.959222       0.020705
# ACUSHNET                             5.147421       0.009308
# ADAMS                                1.299340       0.025827
# AGAWAM                              -0.532425       0.004586
#
# [5 rows x 27 columns]

# %%
#Find Towns where the LatinX pop was greater than 30% in 2016
towns_LatinX_2016 = pres_city.loc[(pres_city['% LatinX 2016'] >= .30)]

# %%
towns_LatinX_2016.shape
# Out:
# (6, 27)

# %%
towns_LatinX_2016
# Out:
#              Total Population 2016  LatinX Population 2016  Mexican 2016  \
# City/Town
# CHELSEA                      52441                   27712           787
# HOLYOKE                      45058                   16675           111
# LAWRENCE                     67102                   48596           297
# LYNN                        102991                   34226          1600
# METHUEN                      62471                   21879           275
# SPRINGFIELD                 167915                   62062          2538
#
#              Puerto Rican 2016  Cuban 2016  Other LatinX 2016  \
# City/Town
# CHELSEA                   4599         217              22109
# HOLYOKE                  15439          41               1084
# LAWRENCE                 13146         447              34706
# LYNN                      5379         155              27092
# METHUEN                   7071         173              14360
# SPRINGFIELD              51688         273               7563
#
#              Total Population 2019  LatinX Population 2019  Mexican 2019  \
# City/Town
# CHELSEA                      54565                   31645          1299
# HOLYOKE                      45343                   18404           217
# LAWRENCE                     67842                   50706           440
# LYNN                        103603                   38091          1839
# METHUEN                      64852                   25768           255
# SPRINGFIELD                 167224                   67004          2087
#
#              Puerto Rican 2019  ...  Total Votes Cast 2020  % LatinX 2016  \
# City/Town                       ...
# CHELSEA                   4502  ...                 7131.0       0.528441
# HOLYOKE                  16586  ...                13320.0       0.370079
# LAWRENCE                 12501  ...                15104.0       0.724211
# LYNN                      3930  ...                28753.0       0.332320
# METHUEN                   6979  ...                26881.0       0.350227
# SPRINGFIELD              56767  ...                33729.0       0.369604
#
#              % LatinX 2019  % Democratic 2016  % Democratic 2020  \
# City/Town
# CHELSEA           0.579951           0.734743           0.766092
# HOLYOKE           0.405884           0.673746           0.657583
# LAWRENCE          0.747413           0.838300           0.734044
# LYNN              0.367663           0.686249           0.701040
# METHUEN           0.397335           0.535401           0.576615
# SPRINGFIELD       0.400684           0.728685           0.697975
#
#              % Republican 2016  % Republican 2020  \
# City/Town
# CHELSEA               0.166442           0.206984
# HOLYOKE               0.248525           0.314715
# LAWRENCE              0.116767           0.242386
# LYNN                  0.237044           0.275728
# METHUEN               0.391613           0.399353
# SPRINGFIELD           0.208310           0.256278
#
#              Democratic Percentage point Change  \
# City/Town
# CHELSEA                                3.134887
# HOLYOKE                               -1.616373
# LAWRENCE                             -10.425567
# LYNN                                   1.479136
# METHUEN                                4.121485
# SPRINGFIELD                           -3.071012
#
#              Republican Percentage point Change  Change LatinX
# City/Town
# CHELSEA                                4.054185       0.051509
# HOLYOKE                                6.618964       0.035805
# LAWRENCE                              12.561895       0.023202
# LYNN                                   3.868417       0.035343
# METHUEN                                0.773999       0.047109
# SPRINGFIELD                            4.796808       0.031080
#
# [6 rows x 27 columns]

# %% [markdown]
# ## See which of those towns had majority Republican support

# %%
towns_LatinX_2016 = towns_LatinX_2016.loc[(towns_LatinX_2016['% Republican 2016'] > towns_LatinX_2016['% Democratic 2016'])]

# %%
towns_LatinX_2016.shape
# Out:
# (0, 27)

# %%
towns_LatinX_2019 = pres_city.loc[(pres_city['% LatinX 2019'] >= .30)]

# %%
towns_LatinX_2019.head()
# Out:
#            Total Population 2016  LatinX Population 2016  Mexican 2016  \
# City/Town
# CHELSEA                    52441                   27712           787
# HOLYOKE                    45058                   16675           111
# LAWRENCE                   67102                   48596           297
# LYNN                      102991                   34226          1600
# METHUEN                    62471                   21879           275
#
#            Puerto Rican 2016  Cuban 2016  Other LatinX 2016  \
# City/Town
# CHELSEA                 4599         217              22109
# HOLYOKE                15439          41               1084
# LAWRENCE               13146         447              34706
# LYNN                    5379         155              27092
# METHUEN                 7071         173              14360
#
#            Total Population 2019  LatinX Population 2019  Mexican 2019  \
# City/Town
# CHELSEA                    54565                   31645          1299
# HOLYOKE                    45343                   18404           217
# LAWRENCE                   67842                   50706           440
# LYNN                      103603                   38091          1839
# METHUEN                    64852                   25768           255
#
#            Puerto Rican 2019  ...  Total Votes Cast 2020  % LatinX 2016  \
# City/Town                     ...
# CHELSEA                 4502  ...                 7131.0       0.528441
# HOLYOKE                16586  ...                13320.0       0.370079
# LAWRENCE               12501  ...                15104.0       0.724211
# LYNN                    3930  ...                28753.0       0.332320
# METHUEN                 6979  ...                26881.0       0.350227
#
#            % LatinX 2019  % Democratic 2016  % Democratic 2020  \
# City/Town
# CHELSEA         0.579951           0.734743           0.766092
# HOLYOKE         0.405884           0.673746           0.657583
# LAWRENCE        0.747413           0.838300           0.734044
# LYNN            0.367663           0.686249           0.701040
# METHUEN         0.397335           0.535401           0.576615
#
#            % Republican 2016  % Republican 2020  \
# City/Town
# CHELSEA             0.166442           0.206984
# HOLYOKE             0.248525           0.314715
# LAWRENCE            0.116767           0.242386
# LYNN                0.237044           0.275728
# METHUEN             0.391613           0.399353
#
#            Democratic Percentage point Change  \
# City/Town
# CHELSEA                              3.134887
# HOLYOKE                             -1.616373
# LAWRENCE                           -10.425567
# LYNN                                 1.479136
# METHUEN                              4.121485
#
#            Republican Percentage point Change  Change LatinX
# City/Town
# CHELSEA                              4.054185       0.051509
# HOLYOKE                              6.618964       0.035805
# LAWRENCE                            12.561895       0.023202
# LYNN                                 3.868417       0.035343
# METHUEN                              0.773999       0.047109
#
# [5 rows x 27 columns]

# %%
towns_LatinX_2019.shape
# Out:
# (6, 27)

# %%
#Find Towns where the LatinX pop was greater than 10 in 2016%
towns_10_2016 = pres_city.loc[(pres_city['% LatinX 2016'] >= .10)]

# %%
towns_10_2016.shape
# Out:
# (39, 27)

# %%
towns_10_2016 = towns_10_2016.loc[(towns_10_2016['% Republican 2016'] > towns_10_2016['% Democratic 2016'])]

# %%
towns_10_2016.shape
# Out:
# (6, 27)

# %%
towns_10_2016
# Out:
#            Total Population 2016  LatinX Population 2016  Mexican 2016  \
# City/Town
# AGAWAM                     48369                    5396           115
# FREETOWN                    4047                     417             0
# LEICESTER                   7215                     764             5
# MILLBURY                   22845                    2571             1
# STERLING                   26863                    2886            52
# WILBRAHAM                  24087                    4880           345
#
#            Puerto Rican 2016  Cuban 2016  Other LatinX 2016  \
# City/Town
# AGAWAM                  4611         111                559
# FREETOWN                 231           0                186
# LEICESTER                552           8                199
# MILLBURY                1784          47                739
# STERLING                1663          11               1160
# WILBRAHAM               4111          36                388
#
#            Total Population 2019  LatinX Population 2019  Mexican 2019  \
# City/Town
# AGAWAM                     48276                    5607           227
# FREETOWN                    3802                     363             0
# LEICESTER                   7103                     471             0
# MILLBURY                   22628                    2712            49
# STERLING                   27086                    3526           107
# WILBRAHAM                  23480                    4486           300
#
#            Puerto Rican 2019  ...  Total Votes Cast 2020  % LatinX 2016  \
# City/Town                     ...
# AGAWAM                  4945  ...                18782.0       0.111559
# FREETOWN                 136  ...                 1856.0       0.103039
# LEICESTER                251  ...                 3277.0       0.105891
# MILLBURY                2000  ...                10747.0       0.112541
# STERLING                2199  ...                13625.0       0.107434
# WILBRAHAM               3667  ...                12008.0       0.202599
#
#            % LatinX 2019  % Democratic 2016  % Democratic 2020  \
# City/Town
# AGAWAM          0.116145           0.423589           0.485412
# FREETOWN        0.095476           0.415150           0.444504
# LEICESTER       0.066310           0.421634           0.476350
# MILLBURY        0.119852           0.428456           0.498372
# STERLING        0.130178           0.429787           0.518165
# WILBRAHAM       0.191056           0.442097           0.527898
#
#            % Republican 2016  % Republican 2020  \
# City/Town
# AGAWAM              0.495315           0.489990
# FREETOWN            0.513799           0.534483
# LEICESTER           0.483590           0.490693
# MILLBURY            0.485407           0.466642
# STERLING            0.456186           0.444917
# WILBRAHAM           0.463689           0.444953
#
#            Democratic Percentage point Change  \
# City/Town
# AGAWAM                               6.182295
# FREETOWN                             2.935457
# LEICESTER                            5.471603
# MILLBURY                             6.991602
# STERLING                             8.837824
# WILBRAHAM                            8.580155
#
#            Republican Percentage point Change  Change LatinX
# City/Town
# AGAWAM                              -0.532425       0.004586
# FREETOWN                             2.068358      -0.007563
# LEICESTER                            0.710262      -0.039580
# MILLBURY                            -1.876552       0.007310
# STERLING                            -1.126896       0.022744
# WILBRAHAM                           -1.873585      -0.011543
#
# [6 rows x 27 columns]

# %%
#Find Towns where the LatinX pop was greater than 10% in 2019
towns_10_2019 = pres_city.loc[(pres_city['% LatinX 2019'] >= .10)]

# %%
towns_10_2019.shape
# Out:
# (36, 27)

# %%
towns_10_2019 = towns_10_2019.loc[(towns_10_2019['% Republican 2020'] > towns_10_2019['% Democratic 2020'])]

# %%
towns_10_2019
# Out:
#            Total Population 2016  LatinX Population 2016  Mexican 2016  \
# City/Town
# AGAWAM                     48369                    5396           115
#
#            Puerto Rican 2016  Cuban 2016  Other LatinX 2016  \
# City/Town
# AGAWAM                  4611         111                559
#
#            Total Population 2019  LatinX Population 2019  Mexican 2019  \
# City/Town
# AGAWAM                     48276                    5607           227
#
#            Puerto Rican 2019  ...  Total Votes Cast 2020  % LatinX 2016  \
# City/Town                     ...
# AGAWAM                  4945  ...                18782.0       0.111559
#
#            % LatinX 2019  % Democratic 2016  % Democratic 2020  \
# City/Town
# AGAWAM          0.116145           0.423589           0.485412
#
#            % Republican 2016  % Republican 2020  \
# City/Town
# AGAWAM              0.495315            0.48999
#
#            Democratic Percentage point Change  \
# City/Town
# AGAWAM                               6.182295
#
#            Republican Percentage point Change  Change LatinX
# City/Town
# AGAWAM                              -0.532425       0.004586
#
# [1 rows x 27 columns]

# %%
#Find Towns 2016 where the LatinX pop is greater than 15%
towns_15_2016 = pres_city.loc[(pres_city['% LatinX 2016'] >= .15)]

# %%
towns_15_2016.shape
# Out:
# (23, 27)

# %%
towns_15_2016 = towns_15_2016.loc[(towns_15_2016['% Republican 2016'] > towns_15_2016['% Democratic 2016'])]

# %%
towns_15_2016
# Out:
#            Total Population 2016  LatinX Population 2016  Mexican 2016  \
# City/Town
# WILBRAHAM                  24087                    4880           345
#
#            Puerto Rican 2016  Cuban 2016  Other LatinX 2016  \
# City/Town
# WILBRAHAM               4111          36                388
#
#            Total Population 2019  LatinX Population 2019  Mexican 2019  \
# City/Town
# WILBRAHAM                  23480                    4486           300
#
#            Puerto Rican 2019  ...  Total Votes Cast 2020  % LatinX 2016  \
# City/Town                     ...
# WILBRAHAM               3667  ...                12008.0       0.202599
#
#            % LatinX 2019  % Democratic 2016  % Democratic 2020  \
# City/Town
# WILBRAHAM       0.191056           0.442097           0.527898
#
#            % Republican 2016  % Republican 2020  \
# City/Town
# WILBRAHAM           0.463689           0.444953
#
#            Democratic Percentage point Change  \
# City/Town
# WILBRAHAM                            8.580155
#
#            Republican Percentage point Change  Change LatinX
# City/Town
# WILBRAHAM                           -1.873585      -0.011543
#
# [1 rows x 27 columns]

# %%
towns_15_2019 = pres_city.loc[(pres_city['% LatinX 2019'] >= .15)]

# %%
towns_15_2019.shape
# Out:
# (25, 27)

# %%
towns_15_2019 = towns_15_2019.loc[(towns_15_2019['% Republican 2020'] > towns_15_2019['% Democratic 2020'])]

# %%
towns_15_2019.shape
# Out:
# (0, 27)

# %% [markdown]
# ## Top 10 Towns with the highest LatinX Percentage

# %%
Top 10 Towns with the highest LatinX Percentage

largest_LatinX = pres_city.nlargest(10, ['% LatinX 2019', 'Republican Percentage point Change'])

# %%
largest_LatinX
# Out:
#              Total Population 2016  LatinX Population 2016  Mexican 2016  \
# City/Town
# LAWRENCE                     67102                   48596           297
# CHELSEA                      52441                   27712           787
# HOLYOKE                      45058                   16675           111
# SPRINGFIELD                 167915                   62062          2538
# METHUEN                      62471                   21879           275
# LYNN                        102991                   34226          1600
# EVERETT                      39641                    9394           202
# REVERE                       46091                   11178           641
# FITCHBURG                    44974                   10155           853
# SHERBORN                     24450                    6091           576
#
#              Puerto Rican 2016  Cuban 2016  Other LatinX 2016  \
# City/Town
# LAWRENCE                 13146         447              34706
# CHELSEA                   4599         217              22109
# HOLYOKE                  15439          41               1084
# SPRINGFIELD              51688         273               7563
# METHUEN                   7071         173              14360
# LYNN                      5379         155              27092
# EVERETT                   1166          53               7973
# REVERE                    1279          83               9175
# FITCHBURG                 6710          34               2558
# SHERBORN                  2225          11               3279
#
#              Total Population 2019  LatinX Population 2019  Mexican 2019  \
# City/Town
# LAWRENCE                     67842                   50706           440
# CHELSEA                      54565                   31645          1299
# HOLYOKE                      45343                   18404           217
# SPRINGFIELD                 167224                   67004          2087
# METHUEN                      64852                   25768           255
# LYNN                        103603                   38091          1839
# EVERETT                      40852                   11215           224
# REVERE                       45426                   12432           542
# FITCHBURG                    46329                   11950          1060
# SHERBORN                     25212                    5860           349
#
#              Puerto Rican 2019  ...  Total Votes Cast 2020  % LatinX 2016  \
# City/Town                       ...
# LAWRENCE                 12501  ...                15104.0       0.724211
# CHELSEA                   4502  ...                 7131.0       0.528441
# HOLYOKE                  16586  ...                13320.0       0.370079
# SPRINGFIELD              56767  ...                33729.0       0.369604
# METHUEN                   6979  ...                26881.0       0.350227
# LYNN                      3930  ...                28753.0       0.332320
# EVERETT                   1620  ...                 9545.0       0.236977
# REVERE                    1862  ...                 7643.0       0.242520
# FITCHBURG                 8446  ...                15794.0       0.225797
# SHERBORN                  2223  ...                14955.0       0.249121
#
#              % LatinX 2019  % Democratic 2016  % Democratic 2020  \
# City/Town
# LAWRENCE          0.747413           0.838300           0.734044
# CHELSEA           0.579951           0.734743           0.766092
# HOLYOKE           0.405884           0.673746           0.657583
# SPRINGFIELD       0.400684           0.728685           0.697975
# METHUEN           0.397335           0.535401           0.576615
# LYNN              0.367663           0.686249           0.701040
# EVERETT           0.274528           0.657777           0.692300
# REVERE            0.273676           0.568050           0.599764
# FITCHBURG         0.257938           0.561271           0.601051
# SHERBORN          0.232429           0.648549           0.757940
#
#              % Republican 2016  % Republican 2020  \
# City/Town
# LAWRENCE              0.116767           0.242386
# CHELSEA               0.166442           0.206984
# HOLYOKE               0.248525           0.314715
# SPRINGFIELD           0.208310           0.256278
# METHUEN               0.391613           0.399353
# LYNN                  0.237044           0.275728
# EVERETT               0.286432           0.286118
# REVERE                0.362517           0.374068
# FITCHBURG             0.345195           0.369634
# SHERBORN              0.226588           0.193581
#
#              Democratic Percentage point Change  \
# City/Town
# LAWRENCE                             -10.425567
# CHELSEA                                3.134887
# HOLYOKE                               -1.616373
# SPRINGFIELD                           -3.071012
# METHUEN                                4.121485
# LYNN                                   1.479136
# EVERETT                                3.452235
# REVERE                                 3.171470
# FITCHBURG                              3.977992
# SHERBORN                              10.939109
#
#              Republican Percentage point Change  Change LatinX
# City/Town
# LAWRENCE                              12.561895       0.023202
# CHELSEA                                4.054185       0.051509
# HOLYOKE                                6.618964       0.035805
# SPRINGFIELD                            4.796808       0.031080
# METHUEN                                0.773999       0.047109
# LYNN                                   3.868417       0.035343
# EVERETT                               -0.031321       0.037551
# REVERE                                 1.155049       0.031156
# FITCHBURG                              2.443880       0.032141
# SHERBORN                              -3.300758      -0.016692
#
# [10 rows x 27 columns]

# %%
insight = pres_city.nlargest(5, ['% LatinX 2019', 'Republican Percentage point Change'])

insight = insight[['% LatinX 2019', 'Democratic Percentage point Change', 'Republican Percentage point Change']]

# %%
insight
# Out:
#              % LatinX 2019  Democratic Percentage point Change  \
# City/Town
# LAWRENCE          0.747413                          -10.425567
# CHELSEA           0.579951                            3.134887
# HOLYOKE           0.405884                           -1.616373
# SPRINGFIELD       0.400684                           -3.071012
# METHUEN           0.397335                            4.121485
#
#              Republican Percentage point Change
# City/Town
# LAWRENCE                              12.561895
# CHELSEA                                4.054185
# HOLYOKE                                6.618964
# SPRINGFIELD                            4.796808
# METHUEN                                0.773999

# %% [markdown]
# ## Percentage of cities that saw an increase in the LatinX pop from 2016-2019

# %%
percent of cities that saw an increase in the LatinX pop from 2016-2019

increase = pres_city[(pres_city['Change LatinX']) > 0].count()[0] / pres_city.shape[0]

decrease = 1 - increase 

print("Increase =", increase)
print("Decrease =", decrease)
# Out:
# Increase = 0.73828125
# Decrease = 0.26171875

# %%
#avg LatinX Percentage change for all Towns in MA
pres_city['Change LatinX'].mean()
# Out:
# 0.0075259252143843975

# %%
#avg Percentage change in Republican Support for all Towns in MA
pres_city['Republican Percentage point Change'].mean()
# Out:
# -0.9359053731964311

# %% [markdown]
# ## Percent of cities that saw an increase in the Republican Support from 2016-2019

# %%
increase = pres_city[(pres_city['Republican Percentage point Change']) > 0].count()[0] / pres_city.shape[0]

decrease = 1 - increase 

print("Increase =", increase)
print("Decrease =", decrease)
# Out:
# Increase = 0.2421875
# Decrease = 0.7578125
